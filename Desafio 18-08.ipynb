# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in c:\python311\lib\site-packages (3.0.1)
# [notice] A new release of pip available: 22.3 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\python311\lib\site-packages (3.1.2)
# [notice] A new release of pip available: 22.3 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: et-xmlfile in c:\python311\lib\site-packages (from openpyxl) (1.1.0)

# %%
import openpyxl
import xlsxwriter as xlsx
import os

def open_file(fileName):
    encoding = input('Insira o encoding do arquivo(ASCII, UTF-16, UTF-8 ou ANSI):')

    try:
        with open(fileName, 'r', encoding=encoding) as file:
            contents = file.read()

            return contents

    except UnicodeDecodeError:
        print('ERRO: Ocorreu um erro no encoding, selecione um tipo correto ')
    except FileNotFoundError:
        print('ERRO: Arquivo não localizado')

arquivo = input('Digite o caminho completo do arquivo: ')
conteudo = open_file(arquivo)

#-----------------------------------------------------------------------------------

# %%
lista_dados = conteudo.splitlines()

#print(lista_dados)

for i in range(0, len(lista_dados)):
    lista_dados[i] = lista_dados[i].split(';')

print(lista_dados)


wb = openpyxl.Workbook()
ws = wb.active

for linha in lista_dados:
    ws.append(linha)

wb.save(filename= 'teste.xlsx')
# Out:
# [['Nº', 'Abertura', 'Fechamento', 'Tempo', 'Status', 'Atendente', 'Cód. Cliente', 'Tipo', 'Descrição'], ['1', '23/08/2015', '23/08/2015', '08:58', 'Fechado', 'Mônica', '578.971.863', 'Reclamação', 'O cuidado em identificar pontos críticos no surgimento do comércio virtual nos obriga à análise das novas proposições.'], ['2', '23/08/2015', '24/08/2015', '19:16', 'Fechado', 'Vitor', '272.955.347', 'Reclamação', 'Por outro lado, a adoção de políticas descentralizadoras auxilia a preparação e a composição dos índices pretendidos.'], ['3', '24/08/2015', '24/08/2015', '21:15', 'Fechado', 'Thiago', '896.241.681', 'Reclamação', 'As experiências acumuladas demonstram que o entendimento das metas propostas maximiza as possibilidades por conta das posturas dos órgãos dirigentes com relação às suas atribuições.'], ['4', '25/08/2015', '25/08/2015', '13:44', 'Fechado', 'Roberta', '294.072.833', 'Reclamação', 'A nível organizacional, o comprometimento entre as equipes deve passar por modificações independentemente do fluxo de informações.'], ['6', '26/08/2015', '27/08/2015', '14:44', 'Fechado', 'Carlos Eduardo', '863.764.886', 'Sugestão', 'A nível organizacional, a contínua expansão de nossa atividade pode nos levar a considerar a reestruturação de todos os recursos funcionais envolvidos.'], ['7', '26/08/2015', '27/08/2015', '07:44', 'Fechado', 'Vitor', '898.250.026', 'Suporte', 'Caros amigos, o desenvolvimento contínuo de distintas formas de atuação representa uma abertura para a melhoria dos níveis de motivação departamental.'], ['8', '27/08/2015', '27/08/2015', '14:51', 'Fechado', 'Mônica', '878.376.895', 'Reclamação', 'Percebemos, cada vez mais, que a competitividade nas transações comerciais aponta para a melhoria das diversas correntes de pensamento.'], ['9', '27/08/2015', '28/08/2015', '08:14', 'Fechado', 'Carlos Eduardo', '426.741.405', 'Reclamação', 'Todas estas questões, devidamente ponderadas, levantam dúvidas sobre se a necessidade de renovação processual auxilia a preparação e a composição dos métodos utilizados na avaliação de resultados.'], ['10', '27/08/2015', '28/08/2015', '09:27', 'Fechado', 'Juliana', '915.647.161', 'Elogio', 'Todas estas questões, devidamente ponderadas, levantam dúvidas sobre se a necessidade de renovação processual auxilia a preparação e a composição dos métodos utilizados na avaliação de resultados.'], ['11', '27/08/2015', '29/08/2015', '38:17', 'Crítico', 'Eduardo', '315.613.644', 'Sugestão', 'A nível organizacional, a consolidação das estruturas afeta positivamente a correta previsão de alternativas às soluções ortodoxas.'], ['12', '28/08/2015', '28/08/2015', '15:17', 'Fechado', 'Carlos Eduardo', '703.476.595', 'Reclamação', 'Do mesmo modo, o surgimento do comércio virtual afeta positivamente a correta previsão dos procedimentos normalmente adotados.'], ['14', '29/08/2015', '31/08/2015', '47:23', 'Crítico', 'Maria Luíza', '660.057.276', 'Suporte', 'As experiências acumuladas demonstram que a adoção de políticas descentralizadoras promove a alavancagem da gestão inovadora da qual fazemos parte.'], ['15', '30/08/2015', '30/08/2015', '04:22', 'Fechado', 'Roberta', '768.353.431', 'Reclamação', 'Assim mesmo, a hegemonia do ambiente político possibilita uma melhor visão global do processo de comunicação como um todo.'], ['16', '30/08/2015', '01/09/2015', '39:52', 'Crítico', 'Mônica', '635.549.863', 'Suporte', 'É importante questionar o quanto o desenvolvimento contínuo de distintas formas de atuação exige a precisão e a definição do remanejamento dos quadros funcionais.'], ['17', '31/08/2015', '31/08/2015', '02:00', 'Fechado', 'Juliana', '671.349.037', 'Sugestão', 'Assim mesmo, o início da atividade geral de formação de atitudes afeta positivamente a correta previsão das diretrizes de desenvolvimento para o futuro.'], ['18', '31/08/2015', '01/09/2015', '17:50', 'Fechado', 'Thiago', '695.429.642', 'Reclamação', 'Por outro lado, a constante divulgação das informações representa uma abertura para a melhoria do ...

# %%
#import openpyxl
#import xlsxwriter as xlsx
#import os

#info_caminho = input('Informe o caminho completo da pasta que se encontra o arquivo: ')
#info_arquivo = input('Informe o nome do arquivo txt: ')
#nome_planilha = input('Digite o nome desejado para o arquivo xlsx: ')

#caminho = info_caminho
#arquivo = info_arquivo

#f = open (caminho + arquivo, 'r', encoding='ANSI')

#arquivo = f.read()

#lista_dados = arquivo.splitlines()

#print(lista_dados)

#for i in range(0, len(lista_dados)):
    #lista_dados[i] = lista_dados[i].split(',')
    #lista_dados[i] = lista_dados[i].split(';')

#print(lista_dados)


#wb = openpyxl.Workbook()
#ws = wb.active

#for linha in lista_dados:
    #ws.append(linha)

#wb.save(filename= nome_planilha)
